# %% [markdown]
# # Task 3.4
#
# We do not throw in a stone, we just drop in a water coloumn, therefore there is no stone present in this simulation.
#
# Moreover we also dont have any innerfriction in our theorectial model and in this numerical model.
#
# ## ToDo
#
# Boundary conditions ... how to make it circular?!

# %%
from src.simulation import Simulation
from src.opt_inital_distr import inital_exp
from src.config import Config

# %%
config_t4 = Config()
sim = Simulation(inital_exp,config_t4)
sim.run()

# %%
times = [0,130,1745]
sim.plot(times=times,save_to="img/t3_water.svg")

# %%
sim.plot_interactive(t_i_steps=5)
# Out:
# interactive(children=(IntSlider(value=1000, description='t_i', max=2002, step=5), Output()), _dom_classes=('wi…
