# %% [markdown]
# # Task 3.1 and 3.2
#
# ## TODO
# ### numerical solution
# wo in den folien

# %%
from src.simulation import Simulation
from src.opt_inital_distr import initial_sin
from src.config import Config

# %%
# just standard config
config_t2 = Config()

sim = Simulation(initial_sin,config_t2)
sim.run()
# Out:
# /Users/leolux/projects/computational_physics_course/assignement_1/task_3/src/simulation.py:66: RuntimeWarning: overflow encountered in multiply
#   + self.alpha * (
# /Users/leolux/projects/computational_physics_course/assignement_1/task_3/src/simulation.py:64: RuntimeWarning: overflow encountered in multiply
#   + 2 * self.U[ i_t-1, self.bc:-self.bc, self.bc:-self.bc ] \
# /Users/leolux/projects/computational_physics_course/assignement_1/task_3/src/simulation.py:64: RuntimeWarning: overflow encountered in subtract
#   + 2 * self.U[ i_t-1, self.bc:-self.bc, self.bc:-self.bc ] \
# /Users/leolux/projects/computational_physics_course/assignement_1/task_3/src/simulation.py:68: RuntimeWarning: overflow encountered in add
#   +     self.U[ i_t-1, self.bc +1 :-self.bc +1, self.bc    :-self.bc   , ]
# /Users/leolux/projects/computational_physics_course/assignement_1/task_3/src/simulation.py:71: RuntimeWarning: overflow encountered in add
#   +     self.U[ i_t-1, self.bc    :-self.bc   , self.bc +1 :-self.bc +1, ]
# /Users/leolux/projects/computational_physics_course/assignement_1/task_3/src/simulation.py:67: RuntimeWarning: overflow encountered in add
#   (                 # d^2/dx^2
# /Users/leolux/projects/computational_physics_course/assignement_1/task_3/src/simulation.py:74: RuntimeWarning: overflow encountered in multiply
#   - 4 *     self.U[ i_t-1, self.bc    :-self.bc   , self.bc    :-self.bc   , ]
# /Users/leolux/projects/computational_physics_course/assignement_1/task_3/src/simulation.py:67: RuntimeWarning: overflow encountered in subtract
#   (                 # d^2/dx^2
# /Users/leolux/projects/computational_physics_course/assignement_1/task_3/src/simulation.py:64: RuntimeWarning: invalid value encountered in add
#   + 2 * self.U[ i_t-1, self.bc:-self.bc, self.bc:-self.bc ] \
# /Users/leolux/projects/computational_physics_course/assignement_1/task_3/src/simulation.py:68: RuntimeWarning: invalid value encountered in add
#   +     self.U[ i_t-1, self.bc +1 :-self.bc +1, self.bc    :-self.bc   , ]
# /Users/leolux/projects/computational_physics_course/assignement_1/task_3/src/simulation.py:71: RuntimeWarning: invalid value encountered in add
#   +     self.U[ i_t-1, self.bc    :-self.bc   , self.bc +1 :-self.bc +1, ]
# /Users/leolux/projects/computational_physics_course/assignement_1/task_3/src/simulation.py:67: RuntimeWarning: invalid value encountered in add
#   (                 # d^2/dx^2

# %%
# plot three points of time 
sim.plot()

# %%
sim.plot_interactive(t_i_steps=5)
# Out:
# interactive(children=(IntSlider(value=1000, description='t', max=2002, step=5), Output()), _dom_classes=('widg…
