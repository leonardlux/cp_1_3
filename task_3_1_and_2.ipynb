# %% [markdown]
# # Task 3.1 and 3.2
#
# ## TODO
# ### numerical solution
# wo in den folien

# %%
from src.simulation import Simulation
from src.opt_inital_distr import initial_sin
from src.config import Config

# %%
# just standard config
config_t2 = Config()

sim = Simulation(initial_sin,config_t2)
sim.run()

# %%
# plot three points of time 
sim.plot(analy=True)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
sim.plot_interactive(t_i_steps=5,analy=True,diff=True)
# Out:
# interactive(children=(IntSlider(value=1000, description='t_i', max=2002, step=5), Output()), _dom_classes=('wi…
