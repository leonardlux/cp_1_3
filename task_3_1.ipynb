# %% [markdown]
# # Task 3.1 and 3.2
#
# ## TODO
# ### numerical solution
# wo in den folien

# %%
from src.simulation import Simulation
from src.opt_inital_distr import initial_sin

# %%
sim = Simulation(initial_sin)
sim.run()

# %%
# plot e point of time 
sim.plot()

# %%
sim.plot_interactive(t_i_steps=5)
# Out:
# interactive(children=(IntSlider(value=250, description='t', max=502, step=5), Output()), _dom_classes=('widget…
